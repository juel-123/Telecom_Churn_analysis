# %% [markdown]
# <a href="https://colab.research.google.com/github/juel-123/Telecom_Churn_analysis/blob/main/EDA_TELECOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Project Name - TELECOM CHURN ANALYSIS*

# %% [markdown]
# *   Project type - EDA
#
# *   Contribution - Indiviaul
#
# *   Member - Juel Behera

# %% [markdown]
# # *Project Summary*

# %% [markdown]
# Telecom companies often Struggle with Customer churn , which refers to the number of customers who leave the company over a given period.
# In this project , we aimed the Churn ratye of the company and identify the factors that contributes to customer churn.

# %% [markdown]
# # *GitHub link -*

# %% [markdown]
# provide link

# %% [markdown]
# #*Problem Statement*

# %% [markdown]
# Orange S.A , formerly France Telecom S.A , is French multinational Telecommunications corporation. The Orange Telecom's Churn Dataset, Consists of cleaned customer activity data (features), along with churn label specifying whether customer cancelled the Subscription .
# Explore and analyzed the data to Discover Key factors responsible for customer churn and come up with ways / recommendations to ensure customer retention.

# %% [markdown]
# ## *Define Business ojective?*

# %% [markdown]
# *   Identify key cause of customer churn
# *   Provides steps to retain the valuable customer

# %% [markdown]
# ##*Loading Data and importing modules*

# %%
# imprting libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###*Dataset loading*

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load dataset
df = pd.read_csv('/content/drive/MyDrive/project data/Telecom Churn.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# dataset First view
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# dataset last view
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# ###*Dataset rows and Columns count*

# %%
# showing no .of Rows and Columns
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# ###*Dataset Information*

# %%
# showing dataset Information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# ###*Duplicate Values*

# %%
# Dataset Duplicate count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###*Missing values / Null values*

# %%
# finding Null values
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ###*What i got to know about the dataset?*

# %% [markdown]
# The given Dataset is from Telecom Industry . The dataset consists of 3333 rows and 20 Columns of customer activity data. The data has Churn labels whether the customer cancelled the Subscription. There is no missing and duplicate values in the dataset.

# %% [markdown]
# ###*Understanding the features in the dataset.*

# %%
# Dataset columns
x = df.columns
print(x)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Getting statistics data
df.describe(include = 'all').T
# Out:
#                          count unique    top  freq        mean        std  \
# State                     3333     51     WV   106         NaN        NaN
# Account length          3333.0    NaN    NaN   NaN  101.064806  39.822106
# Area code               3333.0    NaN    NaN   NaN  437.182418   42.37129
# International plan        3333      2     No  3010         NaN        NaN
# Voice mail plan           3333      2     No  2411         NaN        NaN
# Number vmail messages   3333.0    NaN    NaN   NaN     8.09901  13.688365
# Total day minutes       3333.0    NaN    NaN   NaN  179.775098  54.467389
# Total day calls         3333.0    NaN    NaN   NaN  100.435644  20.069084
# Total day charge        3333.0    NaN    NaN   NaN   30.562307   9.259435
# Total eve minutes       3333.0    NaN    NaN   NaN  200.980348  50.713844
# Total eve calls         3333.0    NaN    NaN   NaN  100.114311  19.922625
# Total eve charge        3333.0    NaN    NaN   NaN    17.08354   4.310668
# ...

# %%
# Getting the no .of. unique values of the different features
def get_unique(df):
  for i in df.columns:
    unique_count = df[i].nunique()
    print(f"The number of items in '{i}' : {unique_count}")

get_unique(df)
# Out:
# The number of items in 'State' : 51
# The number of items in 'Account length' : 212
# The number of items in 'Area code' : 3
# The number of items in 'International plan' : 2
# The number of items in 'Voice mail plan' : 2
# The number of items in 'Number vmail messages' : 46
# The number of items in 'Total day minutes' : 1667
# The number of items in 'Total day calls' : 119
# The number of items in 'Total day charge' : 1667
# The number of items in 'Total eve minutes' : 1611
# The number of items in 'Total eve calls' : 123
# The number of items in 'Total eve charge' : 1440
# The number of items in 'Total night minutes' : 1591
# The number of items in 'Total night calls' : 120
# The number of items in 'Total night charge' : 933
# The number of items in 'Total intl minutes' : 162
# The number of items in 'Total intl calls' : 21
# The number of items in 'Total intl charge' : 162
# The number of items in 'Customer service calls' : 10
# The number of items in 'Churn' : 2

# %% [markdown]
# ###*Variable description*

# %% [markdown]
# *   State : All 51 states.
# *   Accounnt Length : How long account has been active.
# *   Area Code: Code Number of Area.
# *   International Plan: International paln activated (yes,no).
# *   Vmail Plan: Voice mail plan activated (yes,no).
# *   Vmail message: No. of voice mail messages.
# *   Day Mins: Total day minutes used.
# *   Day calls: Total day calls made.
# *   Day Charge: Total day charge.
# *   Eve Mins: Total evening minutes.
# *   Eve calls: Total evening calls.
# *   Eve Charge: Total evening charge.
# *   Night Mins:Total night minutes.
# *   Night Calls: Total night calls.
# *   Night Charge: Total night charge.
# *   Intl mins: Total minutes charged.
# *   Intl calls:Total international calls made.
# *   Intl charge:Total international charge.
# *   Customer service calls : Number of customer service calls made.
# *   Churn : Customer Churn(Target variable True=1,False=2)

# %% [markdown]
# ##*Data Wrangling*

# %% [markdown]
# ###*Data wrangling code*

# %%
#Number of customers churning
print("The no. of customers churning :",df[df['Churn']==True].Churn.sum())

# Churned Customers dataset
df_churn = df[df['Churn']==True]

# Number of unique area code
print("No of unique Area Code:", df['Area code'].nunique())

# Customers with International plans activated
print("No of customers with International plan activated", df[df['International plan']=='Yes']['International plan'].count())

#Customers with Voice mail activated
print("No of customers with Voice Mail plan activated:", df[df['Voice mail plan']=='Yes']['Voice mail plan'].count())

df_churn
# Out:
# The no. of customers churning : 483
# No of unique Area Code: 3
# No of customers with International plan activated 323
# No of customers with Voice Mail plan activated: 922
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# ...

# %%
# % of total customers churning
print("Total no. of customers:", df['Churn'].count())
Perc_churning = (df_churn.Churn.count()/df['Churn'].count())*100
print(f'Percentage of customers churning:{round(Perc_churning,2)}%')
# Out:
# Total no. of customers: 3333
# Percentage of customers churning:14.49%

# %%
# Statewise customer churning
state_cust_churn = df_churn.groupby(['State'])['Churn'].value_counts().reset_index(name='Churn_customers')
print(state_cust_churn.sum())
state_cust_churn
# Out:
# State              AKALARAZCACOCTDCDEFLGAHIIAIDILINKSKYLAMAMDMEMI...
# Churn                                                             51
# Churn_customers                                                  483
# dtype: object
#    State  Churn  Churn_customers
# 0     AK   True                3
# 1     AL   True                8
# 2     AR   True               11
# 3     AZ   True                4
# 4     CA   True                9
# 5     CO   True                9
# 6     CT   True               12
# 7     DC   True                5
# 8     DE   True                9
# 9     FL   True                8
# 10    GA   True                8
# 11    HI   True                3
# 12    IA   True                3
# 13    ID   True                9
# 14    IL   True                5
# 15    IN   True                9
# 16    KS   True               13
# 17    KY   True                8
# 18    LA   True                4
# 19    MA   True               11
# 20    MD   True               17
# ...

# %%
# Account length wise churn data
acc_len_churn = df_churn.groupby(['Account length'])['Churn'].value_counts().reset_index(name='values')
print(acc_len_churn.sum())
acc_len_churn
# Out:
# Account length    17028
# Churn               164
# values              483
# dtype: int64
#      Account length  Churn  values
# 0                 1   True       1
# 1                 2   True       1
# 2                12   True       1
# 3                13   True       1
# 4                16   True       1
# ..              ...    ...     ...
# 159             208   True       1
# 160             209   True       1
# 161             212   True       1
# 162             224   True       1
# 163             225   True       1
#
# [164 rows x 3 columns]

# %%
# Area code wise Churn customer
Area_code_churn_percen = (df.groupby(['Area code'])['Churn'].mean()*100).reset_index()
Area_code_churn_percen
# Out:
#    Area code      Churn
# 0        408  14.558473
# 1        415  14.259819
# 2        510  14.880952

# %%
# Area code wise Churn Count
Area_code_churn_count = df_churn.groupby(['Area code'])['Churn'].value_counts().reset_index(name= 'Counts')
Area_code_churn_count
# Out:
#    Area code  Churn  Counts
# 0        408   True     122
# 1        415   True     236
# 2        510   True     125

# %%
# poor connectivity by interesection of state by area code
Area_state_churn = df_churn.groupby(['Area code'])['State'].unique().reset_index(name='unique state')
Area_state_churn
# Out:
#    Area code                                       unique state
# 0        408  [CO, AZ, MD, NY, IN, MS, VT, VA, KS, SD, RI, O...
# 1        415  [IN, NY, ID, WY, DC, NJ, LA, NV, MS, OH, AK, M...
# 2        510  [TX, ME, MS, FL, MN, OK, SD, WI, DE, KS, OH, W...

# %%
# percentage of customers with and without international plan churning to other networks
intl_plan_churn = (df.groupby(['International plan'])['Churn'].mean()*100).reset_index(name='Churn%')
intl_plan_churn
# Out:
#   International plan     Churn%
# 0                 No  11.495017
# 1                Yes  42.414861

# %%
# percentage of customers with and without Voice mail plan churning to other networks
Voice_mail_plan_churn = (df.groupby(['Voice mail plan'])['Churn'].mean()*100).reset_index(name='Churn%')
Voice_mail_plan_churn
# Out:
#   Voice mail plan     Churn%
# 0              No  16.715056
# 1             Yes   8.676790

# %%
#percentage of customers with no of voice mail messages churning / not churning to other networks
Voice_mail_message_churn = (df.groupby(['Churn'])['Number vmail messages'].mean()).reset_index(name='perc_vmail_messgae')
Voice_mail_message_churn
# Out:
#    Churn  perc_vmail_messgae
# 0  False            8.604561
# 1   True            5.115942

# %%
# Day data
# Percentage of Customers with the avg Day mins,calls and charge
df.groupby(['Churn'])['Total day minutes'].mean().reset_index(name='perc_day_mins')
# Out:
#    Churn  perc_day_mins
# 0  False     175.175754
# 1   True     206.914079

# %%
df.groupby(['Churn'])['Total day calls'].mean().reset_index(name='perc_day_calls')
# Out:
#    Churn  perc_day_calls
# 0  False      100.283158
# 1   True      101.335404

# %%
df.groupby(['Churn'])['Total day charge'].mean().reset_index(name='perc_day_charge')
# Out:
#    Churn  perc_day_charge
# 0  False        29.780421
# 1   True        35.175921

# %%
# Evening data
# Percentage of customers with avg Evening mins,calls,charge.
df.groupby(['Churn'])['Total eve minutes'].mean().reset_index(name='perc_eve_mins')
# Out:
#    Churn  perc_eve_mins
# 0  False     199.043298
# 1   True     212.410145

# %%
df.groupby(['Churn'])['Total eve calls'].mean().reset_index(name='perc_eve_calls')
# Out:
#    Churn  perc_eve_calls
# 0  False      100.038596
# 1   True      100.561077

# %%
df.groupby(['Churn'])['Total eve charge'].mean().reset_index(name='perc_eve_charge')
# Out:
#    Churn  perc_eve_charge
# 0  False        16.918909
# 1   True        18.054969

# %%
# Night data
# Percentage of Customers with the avg Night mins,calls and charge
df.groupby(['Churn'])['Total night minutes'].mean().reset_index(name='perc_night_mins')
# Out:
#    Churn  perc_night_mins
# 0  False       200.133193
# 1   True       205.231677

# %%
df.groupby(['Churn'])['Total night calls'].mean().reset_index(name='perc_night_calls')
# Out:
#    Churn  perc_night_calls
# 0  False        100.058246
# 1   True        100.399586

# %%
df.groupby(['Churn'])['Total night charge'].mean().reset_index(name='perc_night_charge')
# Out:
#    Churn  perc_night_charge
# 0  False           9.006074
# 1   True           9.235528

# %%
# Intl call data
# Percentage of Customers churning with avg international mins, calls, charge
df.groupby(['Churn'])['Total intl minutes'].mean().reset_index(name ='perc_intl_mins')
# Out:
#    Churn  perc_intl_mins
# 0  False       10.158877
# 1   True       10.700000

# %%
df.groupby(['Churn'])['Total intl calls'].mean().reset_index(name ='perc_intl_calls')
# Out:
#    Churn  perc_intl_calls
# 0  False         4.532982
# 1   True         4.163561

# %%
df.groupby(['Churn'])['Total intl charge'].mean().reset_index(name ='perc_intl_charge')
# Out:
#    Churn  perc_intl_charge
# 0  False          2.743404
# 1   True          2.889545

# %% [markdown]
# #*Data visualization and analyzing the relationship*

# %% [markdown]
# ###*Analyze the Churn feature*

# %%
Churn = pd.DataFrame(df['Churn'].value_counts())
Churn
# Out:
#        Churn
# False   2850
# True     483

# %%
df['Churn'].value_counts().plot.pie(explode = [0.05,0.05],autopct= '%1.1f%%', startangle= 90, shadow = True, figsize=(5,5))
plt.title('Pie chart for Churn')
plt.show()

# %% [markdown]
# from this pie chart we can insights that 14.5% of customers get churned and 85.5% are not.

# %% [markdown]
# ###*Visualizing column wise histogram and Boxplot (univariate)*

# %%
for col in df.describe().columns:
  fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(18,6))
  sns.histplot(df[col],ax= axes[0],kde=True)
  sns.boxplot(df[col],ax=axes[1],orient = 'h',showmeans=True,color='red')
  plt.suptitle("Distribution plot of"+ col, fontsize =15  )
  plt.show()

# %% [markdown]
# **Histogram and Boxplot cannot give us whole information regarding data . From this we just see the distribution of the column data.**

# %% [markdown]
# ###*Analyzing the State column*

# %%
#comparing Churn with the State column using countplot
sns.set(style="darkgrid")
plt.figure(figsize=(15,8))
ax = sns.countplot(x = 'State', hue = 'Churn' , data = df )
plt.show()

# %% [markdown]
# **From this Bar chart we can see States having higher churn rate**

# %% [markdown]
# **There is 51 unique state who have different churn rate
#   , From the above analysis we get to know that  NJ, CA, TX, MD, SC has the highest churn rate,
# The reason for the Churn Rate may be due to the low coverage of cellular network**

# %% [markdown]
# ###*Analyzing "Area code" column*

# %%
#calculate Area code vs Churn percentage
Churn_area = pd.DataFrame(df.groupby("Area code")['Churn'].value_counts())
Churn_area['Churn_rate'] = round(Churn_area*100/len(df),2)
Churn_area
# Out:
#                  Churn  Churn_rate
# Area code Churn
# 408       False    716       21.48
#           True     122        3.66
# 415       False   1419       42.57
#           True     236        7.08
# 510       False    715       21.45
#           True     125        3.75

# %%
sns.set(style = "darkgrid")
ax = sns.countplot(x = 'Area code' , hue = "Churn" ,data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **In the above we notice that there are only 3 unique value of area code i.e: 408,415,510 and the churnrate of these Area code is almost same. we don't think there is any kind of relationship between "Area code" and "Churn" due to which customer leaves the operator.**

# %% [markdown]
# ###*Analyzing "Account length" Column*

# %%
# separating Churn and Non Churn customers
Churn_df = df[df['Churn']==bool(True)]
not_Churn_df = df[df['Churn']== bool(False)]

# %%
#Account length vs Churn
sns.distplot(df['Account length'])
plt.show()
# Out:
# <ipython-input-216-d886943d8bac>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Account length'])

# %%
#comparsion of churned Account length and Non Churned Account length
sns.distplot(df['Account length'], color= 'yellow', label = 'All')
sns.distplot(Churn_df["Account length"], color= 'red',hist = False ,label = 'churned')
sns.distplot(not_Churn_df["Account length"], color= 'green',hist = False, label = 'not_churned')
plt.legend()
# Out:
# <ipython-input-217-2709b9fce970>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Account length'], color= 'yellow', label = 'All')
# <ipython-input-217-2709b9fce970>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# **After analyzing various aspects of "Account length" column we didnot find any useful relation to churn, so we are not able to find any connection with the churn as of now . let's see other features.**

# %% [markdown]
# ###*Analyzing "International plan" Column*

# %%
#show the value_counts of International plan
df['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
#calculate International plan vs Chun rate
International_plan_data = pd.DataFrame(df.groupby('International plan')['Churn'].value_counts())
International_plan_data['Churn_Percentage']= round(International_plan_data*100/len(df),2)
International_plan_data
# Out:
#                           Churn  Churn_Percentage
# International plan Churn
# No                 False   2664             79.93
#                    True     346             10.38
# Yes                False    186              5.58
#                    True     137              4.11

# %%
# Analyzing using countplot
sns.countplot(x= 'International plan', hue = "Churn", data = df)
plt.show()

# %% [markdown]
# ***From the above data we get that people who have international plan have higher churn rate than the people who do not have due to might be connectivity issue.***

# %% [markdown]
# ###*Analyzing "Voice mail plan" column*

# %%
#count of the voice mail plan
df['Voice mail plan'].value_counts()
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
# Calculate Voice mail plan vs Churn
Voice_mail_plan_data = pd.DataFrame(df.groupby('Voice mail plan')['Churn'].value_counts())
Voice_mail_plan_data['Churn_percentage']= round(Voice_mail_plan_data*100/len(df),2)
Voice_mail_plan_data
# Out:
#                        Churn  Churn_percentage
# Voice mail plan Churn
# No              False   2008             60.25
#                 True     403             12.09
# Yes             False    842             25.26
#                 True      80              2.40

# %%
# Analyzing using countplot
sns.countplot(x= 'Voice mail plan', hue = "Churn", data = df)
plt.show()

# %% [markdown]
# ***from the data we get that the people who donot have voice mail plan have higher churn rate than the people who are having Voice mail plan this might be due network issue***

# %% [markdown]
# ###*Analyzing "Number vmail messages"*

# %%
# show the data of "Number vmail messages"
df['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9])

# %%
# show the data of "Number vmail messages"
df['Number vmail messages'].value_counts()

# %%
# show the the details of "Number vmail messages"
df['Number vmail messages'].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: Number vmail messages, dtype: float64

# %%
# analyzing using distplot
sns.distplot(df['Number vmail messages'],color = 'red')
# Out:
# <ipython-input-227-ea11f4c8591f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number vmail messages'],color = 'red')
# <Axes: xlabel='Number vmail messages', ylabel='Density'>

# %%
# analyzing using boxplot between "Number vmail messages" and "Churn"
fig = plt.figure(figsize= (10,8))
df.boxplot(column="Number vmail messages", by= "Churn")
fig.suptitle('Number vmail messages', fontsize = 14 , fontweight= 'bold')
plt.show()

# %% [markdown]
# **After analyzing the voice mail feature we get the insight that when there is more than 20 voice mail messages then there is a churn. for that, we need to improve voice mail quality**

# %% [markdown]
# ### Analyze Overall calls

# %%
# Average of all day calls , total day minutes , total day charge
day_calls= pd.DataFrame(df.groupby(['Churn'])['Total day calls'].mean())
print(day_calls)
print('')
day_minutes= pd.DataFrame(df.groupby(['Churn'])['Total day minutes'].mean())
print(day_minutes)
print('')
day_charge= pd.DataFrame(df.groupby(['Churn'])['Total day charge'].mean())
print(day_charge)
# Out:
#        Total day calls
# Churn
# False       100.283158
# True        101.335404
#
#        Total day minutes
# Churn
# False         175.175754
# True          206.914079
#
#        Total day charge
# Churn
# False         29.780421
# True          35.175921

# %%
# visualize total day minutes vs total day charge
plt.figure(figsize=(7,8))
sns.scatterplot(x = 'Total day minutes', y = 'Total day charge',data = df, hue='Churn')
plt.xlabel('Total day minutes',fontsize = 12)
plt.ylabel('Total day charge',fontsize = 12)
plt.title("Total day minutes vs Total day charge",fontsize = 12 )
plt.show()

# %%
# Average of all evening calls , total evening minutes , total evening charge
eve_calls= pd.DataFrame(df.groupby(['Churn'])['Total eve calls'].mean())
print(eve_calls)
print('')
eve_minutes= pd.DataFrame(df.groupby(['Churn'])['Total eve minutes'].mean())
print(eve_minutes)
print('')
eve_charge= pd.DataFrame(df.groupby(['Churn'])['Total eve charge'].mean())
print(eve_charge)
# Out:
#        Total eve calls
# Churn
# False       100.038596
# True        100.561077
#
#        Total eve minutes
# Churn
# False         199.043298
# True          212.410145
#
#        Total eve charge
# Churn
# False         16.918909
# True          18.054969

# %%
# visualize total day minutes vs total day charge
plt.figure(figsize=(7,8))
sns.scatterplot(x = 'Total eve minutes', y = 'Total eve charge',data = df, hue='Churn')
plt.xlabel('Total eve minutes',fontsize = 12)
plt.ylabel('Total eve charge',fontsize = 12)
plt.title("Total eve minutes vs Total eve charge",fontsize = 12 )
plt.show()

# %%
# Average of all Night calls , total night minutes , total night charge
night_calls= pd.DataFrame(df.groupby(['Churn'])['Total night calls'].mean())
print(night_calls)
print('')
night_minutes= pd.DataFrame(df.groupby(['Churn'])['Total night minutes'].mean())
print(night_minutes)
print('')
night_charge= pd.DataFrame(df.groupby(['Churn'])['Total night charge'].mean())
print(night_charge)
# Out:
#        Total night calls
# Churn
# False         100.058246
# True          100.399586
#
#        Total night minutes
# Churn
# False           200.133193
# True            205.231677
#
#        Total night charge
# Churn
# False            9.006074
# True             9.235528

# %%
# visualize total day minutes vs total day charge
plt.figure(figsize=(7,8))
sns.scatterplot(x = 'Total night minutes', y = 'Total night charge',data = df, hue='Churn')
plt.xlabel('Total night minutes',fontsize = 12)
plt.ylabel('Total night charge',fontsize = 12)
plt.title("Total night minutes vs Total night charge",fontsize = 12 )
plt.show()

# %% [markdown]
# **After analyzing the overall calls we can infer that Churn customers speaks more minutes than non-Churn customers in day , evening and night. Hence, they pay more charge than non- churn customers.
# We can reduce churn rate by giving offer plan and charge little less.**

# %% [markdown]
# ###*Analyze "Customer service calls" column*

# %%
# printing the data of Customer service calls
df['Customer service calls'].value_counts()

# %%
# Analyzing using countplot
sns.countplot( x= 'Customer service calls',hue = 'Churn',data = df)
plt.show()

# %% [markdown]
# **Here we can see that when there is 1 Customer service calls the churn is higher**

# %% [markdown]
# ###*Correlation heatmap*

# %%
plt.figure(figsize = (18,12))
corr = df.corr()
sns.heatmap(corr,annot = True)
# Out:
# <ipython-input-239-002d1466ec7c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %% [markdown]
# **From the heatmap we can get the insight that how much each features are strongly correlated with each other**

# %% [markdown]
# **We can see that total day charge and total day minutes , total night charge and total night minute are positve highly correlated with a value 1.Customer service call is positively correlated only with Area code and  negatively correlated with other variables**
#
# **Rest all correlations can be depicted from the above chart**

# %% [markdown]
# #*Solution to business objective*

# %% [markdown]
# **My suggestions to client to reduce customer churn**

# %% [markdown]
# *   Modify international plan to the normal one.
# *   Offer customer with the best plans.
# *   can apply market penetration strategy.
# *   Regular server maintence
# *   solving poor network connectivity issue.
# *   Take regular feedback from the customer.
# *   Analyze churn when it happens.

# %% [markdown]
# ##*Conclusion*

# %% [markdown]
# The Telecommunication industry is already well estabilished and the the rate of new customers is low. Customers basically prefer network which is well reached to all corners of the environment. In this project we analyzed a Churn dataset to identify the main factor effecting churn and gain valuable insights. Through exploratory analysis, we were able to get insights listed below:-
#
#
# 1.   The four charge features are directly related minutes features.
# 2.   The area code feature may not be relevent and can be execluded.
# 3.   Customers with international tends to churn often more.
# 4.   Customers who had fore or more service calls churn significantly than others.
# 5.   Customers with high day and evening minute usage tend to churn at higher rate.
# 6.  There is no clear relationship between churn and variables such as day calls, evening calls, night calls,international minutes, account length and voice mail messages.
